# %%
print("renu sree")
# Out:
# renu sree

# %%
print(1)
# Out:
# 1

# %%
print(1, 2, 3, 4, 5, 6, sep="-")
# Out:
# 1-2-3-4-5-6

# %%
print(1, 2, 3, "renu", 3.4, 1 + 5j, sep=",")
# Out:
# 1,2,3,renu,3.4,(1+5j)

# %%
print("a", end=")")
print("b")
print("c")
# Out:
# a)b
# c

# %%
print("Hello", end=";")
print("World !")
# Out:
# Hello;World !
