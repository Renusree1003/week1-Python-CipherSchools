# %%
2 ** 3
# Out:
# 8

# %%
"Renu" + "Sree"
# Out:
# 'RenuSree'

# %%
"abc" * 6
# Out:
# 'abcabcabcabcabcabc'

# %%
1 == 2
# Out:
# False

# %%
1 !=2
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
"ab" < "z"
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and 1
# Out:
# 1

# %%
1 and 5
# Out:
# 5

# %%
type(True)
# Out:
# bool

# %%
bool("")
# Out:
# False

# %%
112 and " "
# Out:
# ' '
