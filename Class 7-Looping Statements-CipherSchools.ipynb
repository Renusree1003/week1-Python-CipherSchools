# %%
a = 1
while a < 10:
    print(a)
    a += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
print(type(name))
print("***")
for c in name:
    print(c)
    print(type(c))
# Out:
# <class 'str'>
# ***
# r
# <class 'str'>
# e
# <class 'str'>
# n
# <class 'str'>
# u
# <class 'str'>

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
"aaaaaa" * 4
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaa'

# %%
for i in range(5):
    print(i) # 3
    if i == 3: # 3
        break
# Out:
# 0
# 1
# 2
# 3

# %%
for i in (0, 1, 2, 3, 4): # i = 2
    print(i) # i = 2
    i = 100 # i = 100
    print(i) # i = 100
# Out:
# 0
# 100
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100

# %%
for i in range(5):
    print(i)
    if i == 3:
        break
else:
    print("something")
# Out:
# 0
# 1
# 2
# 3
