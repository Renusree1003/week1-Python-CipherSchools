# %%
a = False

if a:
    print("the value is true")
print("end")
# Out:
# end

# %%
a = 5

if a == 3:
    print("this value is 3")
elif a == 5:
    print("this value is 5")
else:
  print("this value is not 3 or 5")
# Out:
# this value is 5
